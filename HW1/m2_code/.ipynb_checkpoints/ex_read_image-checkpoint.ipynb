# %% [markdown]
# # Sample code :  Reading images, scaling, filtering
#
# This is some sample code for reading and scaling images and convolution .

# %% [markdown]
# ### Import statements
#
# The following cell is only for import statements. You can use any of the 3 : cv2, matplotlib or skimage for image i/o and other functions. We will provide you the names of the relevant functions for each module. __{For convenience provided at the end of the class assignment webpage}__

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Reading an image

# %%
img = cv2.imread("woman_park.png")
print(img.shape)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (754, 912, 3)

# %% [markdown]
# ###  Print some small portion of the image, from the first channel

# %%
print(img[0:18,0:18,1])
# Out:
# [[ 95  97 100 103 106 108 109 112 116 123 131 142 154 165 176 179 182 178]
#  [ 97 100 103 105 108 109 110 113 116 121 129 138 149 159 168 172 174 171]
#  [100 102 105 107 109 111 112 113 116 120 126 134 143 152 160 164 166 164]
#  [102 103 105 107 109 110 112 114 116 119 124 130 137 144 152 155 158 157]
#  [103 104 105 107 108 110 112 113 115 117 121 126 131 137 143 146 149 149]
#  [104 105 106 107 107 108 110 111 112 114 116 120 125 130 134 138 141 142]
#  [105 105 105 106 105 106 108 109 110 112 113 116 120 123 126 130 133 135]
#  [106 106 105 103 102 103 107 109 110 111 112 114 115 117 119 122 125 129]
#  [106 106 105 103 101 102 106 109 109 110 111 112 112 113 114 117 120 124]
#  [107 107 106 104 103 103 105 107 108 109 109 110 110 111 112 114 117 121]
#  [106 107 106 106 105 105 105 106 107 107 108 109 109 109 110 112 114 117]
#  [106 107 107 107 107 106 105 105 105 106 107 107 107 107 107 109 110 113]
#  [106 107 107 107 107 107 105 104 105 106 107 107 106 106 106 107 107 109]
#  [105 106 107 107 108 107 105 104 105 106 106 106 106 105 105 105 105 106]
#  [103 105 106 107 107 107 106 106 107 108 108 108 107 106 105 105 104 105]
#  [102 103 105 106 107 107 107 108 109 109 110 110 109 108 106 105 104 104]
#  [101 102 104 106 107 108 108 109 111 112 112 112 112 110 108 106 105 105]
#  [100 102 104 106 107 109 110 111 112 114 115 115 114 112 110 108 106 105]]

# %%
img_gray = (0.2989*img[:,:,0] + 0.5870*img[:,:,1] + 0.1140*img[:,:,2])/255
print(img_gray.shape)
plt.imshow(img_gray, cmap='gray')
plt.show()
