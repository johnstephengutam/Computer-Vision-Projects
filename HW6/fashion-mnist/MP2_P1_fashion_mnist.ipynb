# %% [markdown]
# # Assignment 3 : Image Classification on Fashion MNIST

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import Classifier
from fashion_mnist_dataloader import fashion_mnist_dataset, load_mnist, FASHION_MNIST_CLASSES


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this assignment, you train a classifier to do classificaton on the Fashion-MNIST dataset. The dataset has 10 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is like the ImageNet competition where only a single most appropriate class is predicted for an image.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            #transforms.Resize(227),
            #transforms.CenterCrop(227),
            #transforms.ToTensor(),
            #normalize
        ])

# %%
ds_train = fashion_mnist_dataset('train', train_transform)
len(ds_train)
# Out:
# 50000

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the Fashion-MNIST dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            #transforms.Resize(227),
            #transforms.CenterCrop(227),
            #transforms.ToTensor(),
            #normalize,
        ])

# %%
ds_val = fashion_mnist_dataset('val', test_transform)
len(ds_val)
# Out:
# 10000

# %% [markdown]
# ### Visualizing the Data
#
#  Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
X_train, Y_train = load_mnist('fashion-mnist', kind='train')
mask = list(range(len(ds_train)))
X_train = X_train[mask]

for i in range(5):
    idx = np.random.randint(0, len(ds_train))
    img, label = X_train[idx], Y_train[idx]
    img = img.reshape((28, 28))
    plt.figure(figsize = (2,2))
    plt.title(f'{FASHION_MNIST_CLASSES[label]}')
    plt.imshow(img)

# %% [markdown]
# # Classification

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=64, 
                                               shuffle=True,
                                               num_workers=1)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=5, 
                                               shuffle=False,
                                               num_workers=1)

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    losses_plot = []
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
        losses_plot.append(loss.detach().item())

    return torch.stack(losses).mean().item(), losses_plot

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0))
        y_score = np.zeros((0,10))
        for i, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        
        B = y_true.shape[0]
        y_true_one_hot = np.zeros((B, 10))
        y_true_one_hot[np.arange(B), y_true.astype(np.int16)] = 1

        for i in range(10):
            ap = average_precision_score(y_true_one_hot[:, i], y_score[:, i])
            if print_ind_classes:
                print(f'-------  Class: {i}     AP: {ap:>8.4f}  -------')
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        print('mAP: {0:.4f}'.format(mAP))
        print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %% [markdown]
# ## Modifying the network
#
# The network you are given as is will allow you to reach around 0.15-0.2 mAP. To meet the benchmark for this assignment you will need to improve the network. There are a variety of different approaches you should try:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper

# %%
classifier = Classifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
# Training the Classifier
NUM_EPOCHS = 25
TEST_FREQUENCY = 5

for epoch in range(1, NUM_EPOCHS+1):
    print("Starting epoch number " + str(epoch))
    train_loss, losses = train_classifier(train_loader, classifier, criterion, optimizer)
    print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
    if(epoch%TEST_FREQUENCY==0):
        mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
        print('Evaluating classifier')
        print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.6475986242294312
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.44738075137138367
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.40190213918685913
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.37704843282699585
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.35176199674606323
# -------  Class: 0     AP:   0.8574  -------
# -------  Class: 1     AP:   0.9818  -------
# -------  Class: 2     AP:   0.6418  -------
# -------  Class: 3     AP:   0.8600  -------
# -------  Class: 4     AP:   0.7532  -------
# -------  Class: 5     AP:   0.7309  -------
# -------  Class: 6     AP:   0.4409  -------
# -------  Class: 7     AP:   0.7999  -------
# -------  Class: 8     AP:   0.9669  -------
# -------  Class: 9     AP:   0.9635  -------
# mAP: 0.7996
# Avg loss: 0.36673679314980107
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.7996292637741303
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.33574944734573364
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.32229143381118774
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.31021803617477417
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.30184945464134216
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.29170966148376465
# -------  Class: 0     AP:   0.8600  -------
# -------  Class: 1     AP:   0.9865  -------
# -------  Class: 2     AP:   0.6574  -------
# -------  Class: 3     AP:   0.8817  -------
# -------  Class: 4     AP:   0.7743  -------
# -------  Class: 5     AP:   0.8087  -------
# -------  Class: 6     AP:   0.5370  -------
# -------  Class: 7     AP:   0.7613  -------
# -------  Class: 8     AP:   0.9723  -------
# -------  Class: 9     AP:   0.9679  -------
# mAP: 0.8207
# Avg loss: 0.35742545853714547
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.8207110453738174
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.28281474113464355
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.2751903533935547
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.26797738671302795
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.25869864225387573
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.25437426567077637
# -------  Class: 0     AP:   0.8581  -------
# -------  Class: 1     AP:   0.9899  -------
# -------  Class: 2     AP:   0.7011  -------
# -------  Class: 3     AP:   0.8938  -------
# -------  Class: 4     AP:   0.7673  -------
# -------  Class: 5     AP:   0.8071  -------
# -------  Class: 6     AP:   0.5236  -------
# -------  Class: 7     AP:   0.7902  -------
# -------  Class: 8     AP:   0.9767  -------
# -------  Class: 9     AP:   0.9717  -------
# mAP: 0.8279
# Avg loss: 0.31348345666896055
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.8279494696078018
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.24848029017448425
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.2403765171766281
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.23601318895816803
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.23193182051181793
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.22677570581436157
# -------  Class: 0     AP:   0.8649  -------
# -------  Class: 1     AP:   0.9900  -------
# -------  Class: 2     AP:   0.6926  -------
# -------  Class: 3     AP:   0.9000  -------
# -------  Class: 4     AP:   0.7531  -------
# -------  Class: 5     AP:   0.8872  -------
# -------  Class: 6     AP:   0.5196  -------
# -------  Class: 7     AP:   0.7577  -------
# -------  Class: 8     AP:   0.9796  -------
# -------  Class: 9     AP:   0.9725  -------
# mAP: 0.8317
# Avg loss: 0.3102762464794523
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.8317062544853586
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.22020474076271057
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.21695251762866974
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.21170292794704437
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.20801417529582977
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.20121344923973083
# -------  Class: 0     AP:   0.8627  -------
# -------  Class: 1     AP:   0.9921  -------
# -------  Class: 2     AP:   0.6597  -------
# -------  Class: 3     AP:   0.8896  -------
# -------  Class: 4     AP:   0.7675  -------
# -------  Class: 5     AP:   0.8847  -------
# -------  Class: 6     AP:   0.5610  -------
# -------  Class: 7     AP:   0.6939  -------
# -------  Class: 8     AP:   0.9816  -------
# -------  Class: 9     AP:   0.9729  -------
# mAP: 0.8266
# Avg loss: 0.3158959770872634
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.8265868757447011

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './fashion_mnist_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = fashion_mnist_dataset('test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# -------  Class: 0     AP:   0.8276  -------
# -------  Class: 1     AP:   0.9923  -------
# -------  Class: 2     AP:   0.6551  -------
# -------  Class: 3     AP:   0.8820  -------
# -------  Class: 4     AP:   0.7600  -------
# -------  Class: 5     AP:   0.9044  -------
# -------  Class: 6     AP:   0.5650  -------
# -------  Class: 7     AP:   0.7186  -------
# -------  Class: 8     AP:   0.9813  -------
# -------  Class: 9     AP:   0.9738  -------
# mAP: 0.8260
# Avg loss: 0.3385199719853699

# %%
output_submission_csv('my_solution.csv', test_aps)
